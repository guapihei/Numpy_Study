# %% [markdown]
# # Numpy学习
# ## 导包

# %%
import numpy as np

# %% [markdown]
# ## 查看属性

# %%
arr = np.array([[1,2,3],[4,5,6]])
print(arr)
print('数组形状:', arr.shape)
print('元素个数:', arr.size)
print('数组维度：', arr.ndim)
print('元素数据类型:', arr.dtype)
print('转置:', arr.T)
# Out:
# [[1 2 3]
#  [4 5 6]]
# 数组形状: (2, 3)
# 元素个数: 6
# 数组维度： 2
# 元素数据类型: int64
# 转置: [[1 4]
#  [2 5]
#  [3 6]]
